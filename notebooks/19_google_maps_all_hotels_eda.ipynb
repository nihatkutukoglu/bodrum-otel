# %% [markdown]
# # Google Maps All-Hotels — EDA
# Coverage, rating groups, hotel/area sample sizes, and readiness. Sample fraction is descriptive and is not a representativeness measure. No hotel quality ranking is produced.

# %%
from pathlib import Path
import sys, pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bodrum_intelligence.google_maps_all_hotels_nlp import build_eda_reports
targets = pd.read_csv(ROOT / 'data/raw/google_maps_all_hotels/google_maps_all_hotels_targets.csv')
clean = pd.read_csv(ROOT / 'data/processed/google_maps_all_hotels_reviews_clean.csv')
features = pd.read_csv(ROOT / 'data/processed/google_maps_all_hotels_hotel_nlp_features.csv')
hotel_eda, area_eda = build_eda_reports(targets, clean, features, ROOT / 'reports')
hotel_eda.head(), area_eda.head()
