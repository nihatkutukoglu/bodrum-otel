# %% [markdown]
# # Google Maps All-Hotels — NLP & Aspect Drivers
# Uses the existing 18-aspect canonical taxonomy read-only. Missing data stays NaN and driver fields require the declared LOW/HIGH sample gates.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bodrum_intelligence.google_maps_all_hotels_nlp import run_nlp
summary = run_nlp(
    ROOT / 'data/processed/google_maps_all_hotels_reviews_clean.csv',
    ROOT / 'data/raw/google_maps_all_hotels/google_maps_all_hotels_targets.csv',
    ROOT / 'data/processed', ROOT / 'reports',
    ROOT / 'reports/figures/google_maps_all_hotels')
summary
