# %% [markdown]
# # Google Maps All-Hotels — Audit & Cleaning
# Isolated audit for the public, capped all-hotels review sample. Raw text remains unchanged; rating-only rows are retained for distributions and excluded from NLP.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bodrum_intelligence.google_maps_all_hotels_cleaning import run_cleaning
clean, readiness, audit = run_cleaning(
    ROOT / 'data/raw/google_maps_all_hotels/google_maps_all_hotels_reviews_raw.csv',
    ROOT / 'data/raw/google_maps_all_hotels/google_maps_all_hotels_targets.csv',
    ROOT / 'data/processed', ROOT / 'reports')
audit, readiness.head()
